# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# !pip install statsmodels

# %%
df = pd.read_csv("exoplanet_data.csv")
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df = df.drop(columns="koi_disposition")
df.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = df.columns

vif_data["VIF"] = [variance_inflation_factor(df.values, i)
                          for i in range(len(df.columns))]
# Out:
# c:\Users\david\Anaconda3\envs\PythonAdv\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
vif_data
# Out:
#               feature         VIF
# 0       koi_fpflag_nt    1.779518
# 1       koi_fpflag_ss    2.258031
# 2       koi_fpflag_co    2.026124
# 3       koi_fpflag_ec    1.685255
# 4          koi_period    4.004765
# 5     koi_period_err1         inf
# 6     koi_period_err2         inf
# 7         koi_time0bk   12.609776
# 8    koi_time0bk_err1         inf
# 9    koi_time0bk_err2         inf
# 10         koi_impact    7.242275
# 11    koi_impact_err1    1.179430
# 12    koi_impact_err2    3.828811
# 13       koi_duration    2.425411
# 14  koi_duration_err1         inf
# 15  koi_duration_err2         inf
# 16          koi_depth    2.067019
# 17     koi_depth_err1         inf
# 18     koi_depth_err2         inf
# 19           koi_prad   82.527440
# 20      koi_prad_err1    3.420750
# 21      koi_prad_err2   66.105319
# 22            koi_teq    8.011333
# 23          koi_insol   35.247832
# 24     koi_insol_err1   10.091661
# 25     koi_insol_err2   23.902964
# 26      koi_model_snr    2.013813
# 27   koi_tce_plnt_num    5.058947
# 28          koi_steff  114.662836
# 29     koi_steff_err1   46.062711
# 30     koi_steff_err2   26.930072
# 31          koi_slogg  381.263520
# 32     koi_slogg_err1    3.452486
# 33     koi_slogg_err2    6.389045
# 34           koi_srad    8.051562
# 35      koi_srad_err1    4.349566
# 36      koi_srad_err2    6.490666
# 37                 ra  722.055118
# 38                dec  146.967856
# 39         koi_kepmag  185.342556
